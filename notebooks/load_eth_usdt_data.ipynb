# %%
from load_files import *

OUTPUT_DIR = "eth_parquet_data"
os.makedirs(OUTPUT_DIR, exist_ok=True)

pair = "BTCUSD"
start_date = "2014-01-17"
end_date = "2025-01-16"

process_date_range(pair, start_date, end_date)
# Out:
# ...
# Saved 2024-01-17 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-17.parquet
# ...
# Saved 2024-01-18 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-18.parquet
# ...
# Saved 2024-01-19 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-19.parquet
# ...
# Saved 2024-01-20 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-20.parquet
# ...
# Saved 2024-01-21 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-21.parquet
# ...
# Saved 2024-01-22 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-22.parquet
# ...
# Saved 2024-01-23 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-23.parquet
# ...
# Saved 2024-01-24 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-24.parquet
# ...
# Saved 2024-01-25 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-25.parquet
# ...
# Saved 2024-01-26 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-26.parquet
# ...
# Saved 2024-01-27 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-27.parquet
# ...
# Saved 2024-01-28 data to eth_parquet_data/2024/01/ETHUSDT-1s-2024-01-28.parquet
# ...
